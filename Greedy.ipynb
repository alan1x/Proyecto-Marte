# %%
from Greedy_robot import *
import numpy as np
mars_map = np.load("mars_map.npy")
crater_map = np.load("crater_map.npy")

# %% [markdown]
# # Superficie en Marte

# %%
x_start, y_start = 2850, 6400
x_goal, y_goal = 3150, 6800
camino_recorrido(mars_map,x_start,y_start,x_goal,y_goal)
# Out:
# La solución es: [(2854.9590000000003, 6401.1186), (2864.9764, 6411.136), (2874.9938, 6421.1534), (2885.0112, 6431.1708), (2895.0286, 6441.1882000000005), (2905.0460000000003, 6451.2056), (2915.0634, 6461.223), (2925.0808, 6471.240400000001), (2935.0982, 6481.2578), (2945.1156, 6491.2752), (2955.1330000000003, 6501.2926), (2965.1504, 6511.31), (2975.1678, 6521.3274), (2985.1852, 6531.3448), (2995.2026, 6541.3622000000005), (3005.2200000000003, 6551.3796), (3015.2374, 6561.397), (3025.2548, 6571.414400000001), (3035.2722, 6581.4318), (3045.2896, 6591.4492), (3055.3070000000002, 6601.466600000001), (3065.3244, 6611.484), (3075.3418, 6621.5014), (3085.3592, 6631.5188), (3095.3766, 6641.5362000000005), (3105.3940000000002, 6651.5536), (3115.4114, 6661.571), (3125.4288, 6671.588400000001), (3135.4462000000003, 6681.6058), (3145.4636, 6691.6232), (3145.4636, 6701.640600000001), (3145.4636, 6711.658), (3145.4636, 6721.6754), (3145.4636, 6731.6928), (3145.4636, 6741.7102), (3145.4636, 6751.72
# ...

# %%
x_start, y_start = 2850, 6400
x_goal, y_goal = 3150, 5000
camino_recorrido(mars_map,x_start,y_start,x_goal,y_goal)
# Out:
# La solución es: [(2854.9590000000003, 6401.1186), (2864.9764, 6391.1012), (2874.9938, 6381.0838), (2885.0112, 6371.066400000001), (2895.0286, 6361.049), (2905.0460000000003, 6351.0316), (2915.0634, 6341.0142000000005), (2925.0808, 6330.9968), (2935.0982, 6320.9794), (2945.1156, 6310.962), (2955.1330000000003, 6300.9446), (2965.1504, 6290.9272), (2975.1678, 6280.9098), (2985.1852, 6270.892400000001), (2995.2026, 6260.875), (3005.2200000000003, 6250.8576), (3015.2374, 6240.840200000001), (3025.2548, 6230.8228), (3035.2722, 6220.8054), (3045.2896, 6210.7880000000005), (3055.3070000000002, 6200.7706), (3065.3244, 6190.7532), (3075.3418, 6180.7358), (3085.3592, 6170.7184), (3095.3766, 6160.701), (3105.3940000000002, 6150.6836), (3115.4114, 6140.666200000001), (3125.4288, 6130.6488), (3135.4462000000003, 6120.6314), (3145.4636, 6110.6140000000005), (3145.4636, 6100.5966), (3145.4636, 6090.5792), (3145.4636, 6080.5618), (3145.4636, 6070.5444), (3145.4636, 6060.527), (3145.4636, 6050.5096), 
# ...

# %%
x_start, y_start = 2850, 6400
x_goal, y_goal = 6000, 7000
camino_recorrido(mars_map,x_start,y_start,x_goal,y_goal)
# Out:
# La solución es: [(2854.9590000000003, 6401.1186), (2864.9764, 6411.136), (2874.9938, 6421.1534), (2885.0112, 6431.1708), (2895.0286, 6441.1882000000005), (2905.0460000000003, 6451.2056), (2915.0634, 6461.223), (2925.0808, 6471.240400000001), (2935.0982, 6481.2578), (2945.1156, 6491.2752), (2955.1330000000003, 6501.2926), (2965.1504, 6511.31), (2975.1678, 6521.3274), (2985.1852, 6531.3448), (2995.2026, 6541.3622000000005), (3005.2200000000003, 6551.3796), (3015.2374, 6561.397), (3025.2548, 6571.414400000001), (3035.2722, 6581.4318), (3045.2896, 6591.4492), (3055.3070000000002, 6601.466600000001), (3065.3244, 6611.484), (3075.3418, 6621.5014), (3085.3592, 6631.5188), (3095.3766, 6641.5362000000005), (3105.3940000000002, 6651.5536), (3115.4114, 6661.571), (3125.4288, 6671.588400000001), (3135.4462000000003, 6681.6058), (3145.4636, 6691.6232), (3155.481, 6701.640600000001), (3165.4984, 6711.658), (3175.5158, 6721.6754), (3185.5332000000003, 6731.6928), (3195.5506, 6741.7102), (3205.568, 
# ...

# %% [markdown]
# # Cráter en Marte

# %%
x_start, y_start = 3800, 8000
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(3796.5946, 8003.9026), (3786.5772, 7993.885200000001), (3776.5598, 7983.8678), (3766.5424000000003, 7973.8504), (3756.525, 7963.8330000000005), (3746.5076, 7953.8156), (3736.4902, 7943.7982), (3726.4728, 7933.7808), (3716.4554000000003, 7923.7634), (3706.438, 7913.746), (3696.4206, 7903.7286), (3686.4032, 7893.711200000001), (3676.3858, 7883.6938), (3666.3684000000003, 7873.6764), (3656.351, 7863.659000000001), (3646.3336, 7853.6416), (3636.3162, 7843.6242), (3626.2988, 7833.6068000000005), (3616.2814000000003, 7823.5894), (3606.264, 7813.572), (3596.2466, 7803.5546), (3586.2292, 7793.537200000001), (3576.2118, 7783.5198), (3566.1944000000003, 7773.5024), (3556.177, 7763.485000000001), (3546.1596, 7753.4676), (3536.1422000000002, 7743.4502), (3526.1248, 7733.4328000000005), (3516.1074000000003, 7723.4154), (3506.09, 7713.398), (3496.0726, 7703.3806), (3486.0552000000002, 7693.3632), (3476.0378, 7683.3458), (3466.0204, 7673.3284), (3456.003, 7663.311000000001), (3445
# ...

# %%
x_start, y_start = 6300, 1000
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(6300.9446, 1001.74), (6290.9272, 1011.7574000000001), (6280.9098, 1021.7748), (6270.892400000001, 1031.7922), (6260.875, 1041.8096), (6250.8576, 1051.827), (6240.840200000001, 1061.8444), (6230.8228, 1071.8618000000001), (6220.8054, 1081.8792), (6210.7880000000005, 1091.8966), (6200.7706, 1101.914), (6190.7532, 1111.9314), (6180.7358, 1121.9488000000001), (6170.7184, 1131.9662), (6160.701, 1141.9836), (6150.6836, 1152.001), (6140.666200000001, 1162.0184), (6130.6488, 1172.0358), (6120.6314, 1182.0532), (6110.6140000000005, 1192.0706), (6100.5966, 1202.088), (6090.5792, 1212.1054000000001), (6080.5618, 1222.1228), (6070.5444, 1232.1402), (6060.527, 1242.1576), (6050.5096, 1252.175), (6040.492200000001, 1262.1924000000001), (6030.4748, 1272.2098), (6020.4574, 1282.2272), (6010.4400000000005, 1292.2446), (6000.4226, 1302.262), (5990.4052, 1312.2794000000001), (5980.3878, 1322.2968), (5970.3704, 1332.3142), (5960.353, 1342.3316), (5950.3356, 1352.349), (5940.31820000000
# ...

# %%
x_start, y_start = 500, 9500
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(500.87, 9496.4952), (510.8874, 9486.4778), (520.9048, 9476.4604), (530.9222, 9466.443000000001), (540.9396, 9456.4256), (550.957, 9446.4082), (560.9744000000001, 9436.390800000001), (570.9918, 9426.3734), (581.0092, 9416.356), (591.0266, 9406.338600000001), (601.044, 9396.3212), (601.044, 9386.3038), (611.0614, 9376.2864), (621.0788, 9366.269), (631.0962000000001, 9356.2516), (641.1136, 9346.2342), (651.131, 9336.2168), (661.1484, 9326.1994), (671.1658, 9316.182), (671.1658, 9306.1646), (681.1832, 9296.1472), (691.2006, 9286.1298), (701.2180000000001, 9276.1124), (711.2354, 9266.095000000001), (721.2528, 9256.0776), (731.2702, 9246.0602), (741.2876, 9236.042800000001), (751.3050000000001, 9226.0254), (761.3224, 9216.008), (771.3398, 9205.990600000001), (781.3572, 9195.9732), (781.3572, 9185.9558), (781.3572, 9175.938400000001), (781.3572, 9165.921), (791.3746, 9155.9036), (791.3746, 9145.8862), (791.3746, 9135.8688), (791.3746, 9125.8514), (791.3746, 9115.834), (781
# ...

# %%
x_start, y_start = 2000, 6000

camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(2003.48, 6000.4226), (2013.4974, 5990.4052), (2013.4974, 5980.3878), (2013.4974, 5970.3704), (2023.5148000000002, 5960.353), (2033.5322, 5950.3356), (2043.5496, 5940.318200000001), (2053.567, 5930.3008), (2063.5844, 5920.2834), (2073.6018, 5910.2660000000005), (2083.6192, 5900.2486), (2093.6366000000003, 5890.2312), (2103.654, 5880.2138), (2113.6714, 5870.1964), (2123.6888, 5860.179), (2133.7062, 5850.1616), (2133.7062, 5840.1442), (2133.7062, 5830.1268), (2133.7062, 5820.1094), (2123.6888, 5810.092000000001), (2113.6714, 5800.0746), (2103.654, 5790.0572), (2103.654, 5780.0398000000005), (2113.6714, 5790.0572), (2123.6888, 5800.0746), (2133.7062, 5810.092000000001), (2133.7062, 5800.0746), (2143.7236000000003, 5790.0572), (2153.741, 5780.0398000000005), (2163.7584, 5790.0572), (2163.7584, 5780.0398000000005), (2173.7758, 5790.0572), (2173.7758, 5780.0398000000005), (2183.7932, 5770.0224), (2193.8106000000002, 5760.005), (2203.828, 5749.9876), (2213.8454, 5739.9702),
# ...

# %%
x_start, y_start = 2600, 4500
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(2604.524, 4497.8126), (2604.524, 4507.83), (2604.524, 4517.847400000001), (2604.524, 4527.8648), (2604.524, 4537.8822), (2594.5066, 4537.8822), (2604.524, 4547.8996), (2614.5414, 4557.917), (2624.5588000000002, 4567.9344), (2624.5588000000002, 4577.9518), (2634.5762, 4587.9692000000005), (2634.5762, 4597.9866), (2624.5588000000002, 4597.9866), (2634.5762, 4608.004), (2624.5588000000002, 4608.004), (2614.5414, 4597.9866), (2604.524, 4597.9866), (2614.5414, 4608.004), (2624.5588000000002, 4618.0214000000005), (2614.5414, 4628.0388), (2624.5588000000002, 4638.0562), (2634.5762, 4648.0736), (2634.5762, 4658.091), (2624.5588000000002, 4668.1084), (2614.5414, 4678.1258), (2604.524, 4688.1432), (2594.5066, 4698.1606), (2584.4892, 4708.178), (2574.4718000000003, 4718.1954000000005), (2564.4544, 4728.2128), (2564.4544, 4738.2302), (2574.4718000000003, 4728.2128), (2584.4892, 4718.1954000000005), (2594.5066, 4708.178), (2604.524, 4698.1606), (2614.5414, 4688.1432), (2624.5588
# ...
