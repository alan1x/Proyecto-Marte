# %%
from funciones2 import *
import numpy as np
crater_map = np.load('../../Datos/crater_map.npy')
nr, nc = crater_map.shape
scale=10.045

# %%
imagen_simple(crater_map,nc, nr, scale)
# Out:
# /home/alaiinx/codigos/marte/Descenso_crater/funciones2.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Recocido Simulado

# %%
origen=(4100,5000)
t0=100000
tf=1
alpha=0.9999
mejor=300
for x in range(20):
    camino=recocido(crater_map,origen,t0,tf,alpha,2000)
    if altura_nodo(crater_map,camino[-1])<mejor:
        mejor=altura_nodo(crater_map,camino[-1])
        mejor_camino=camino


print(mejor_camino[-10:-1])
print(altura_nodo(crater_map,origen))
print(altura_nodo(crater_map,mejor_camino[-1]))
# Out:
# [(3704, 5401), (3703, 5402), (3702, 5402), (3702, 5401), (3703, 5402), (3702, 5401), (3701, 5400), (3700, 5400), (3699, 5399)]
# 128.6042919921877
# 100.21520507812522

# %%
imagen2(camino,origen,crater_map,nc,nr)
