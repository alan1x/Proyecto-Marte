# %%
from funciones2 import *
import numpy as np
crater_map = np.load('../Datos/crater_map.npy')
nr, nc = crater_map.shape
scale=10.045

# %%
imagen_simple(crater_map,nc, nr, scale)
# Out:
# /home/alaiinx/codigos/marte/Descenso_crater/funciones2.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Recocido Simulado

# %%
origen=(2000,5000)
t0=100000
tf=1
alpha=0.9999
camino=recocido(crater_map,origen,t0,tf,alpha,2000)
print(camino[0:10])
print(altura_nodo(crater_map,camino[-1]))
# Out:
# [(2000, 5000), (2001, 5000), (2000, 5001), (2001, 5001), (2002, 5000), (2002, 4999), (2001, 5000), (2002, 4999), (2001, 4998), (2000, 4998)]
# 111.79236572265647

# %%
imagen2(camino,origen,crater_map,nc,nr)
