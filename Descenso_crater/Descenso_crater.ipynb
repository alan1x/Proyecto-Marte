# %%
from funciones2 import *
import numpy as np
mars_map = np.load('../Datos/crater_map.npy')
nr, nc = mars_map.shape
scale=10.045

# %%
imagen_simple(mars_map,nc, nr, scale)
# Out:
# /home/alaiinx/codigos/marte/Descenso_crater/funciones2.py:62: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
