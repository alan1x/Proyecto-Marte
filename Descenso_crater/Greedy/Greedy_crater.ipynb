# %%
from Greedy_funcion import *
import numpy as np
crater_map = np.load("../../Datos/crater_map.npy")

# %% [markdown]
# # Cráter

# %%
x_start, y_start = 3350, 5800
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(3344.985, 5795.965), (3344.985, 5785.92), (3334.94, 5775.875), (3344.985, 5765.83), (3344.985, 5755.785), (3334.94, 5745.74), (3324.895, 5735.695), (3314.85, 5735.695), (3304.805, 5725.65), (3294.7599999999998, 5715.605), (3284.715, 5705.56), (3274.67, 5695.515), (3284.715, 5695.515), (3274.67, 5705.56), (3264.625, 5695.515), (3274.67, 5685.47), (3264.625, 5685.47), (3254.58, 5685.47), (3244.535, 5685.47), (3234.49, 5695.515), (3234.49, 5685.47), (3244.535, 5675.425), (3254.58, 5665.38), (3254.58, 5655.335), (3254.58, 5645.29), (3254.58, 5635.245), (3264.625, 5625.2), (3254.58, 5625.2), (3244.535, 5625.2), (3244.535, 5615.155), (3234.49, 5605.11), (3224.445, 5595.065), (3214.4, 5585.0199999999995), (3204.355, 5574.975), (3194.31, 5564.93), (3184.265, 5554.885), (3174.22, 5544.84), (3164.175, 5534.795), (3154.13, 5524.75), (3144.085, 5524.75), (3134.04, 5524.75), (3123.995, 5524.75), (3113.95, 5524.75), (3103.905, 5524.75), (3103.905, 5514.705), (3093.86, 5514.705), 
# ...

# %%
x_start, y_start = 2000, 5000
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(1998.955, 5002.41), (2009.0, 4992.365), (2019.045, 4992.365), (2029.09, 4992.365), (2039.135, 4992.365), (2049.18, 4992.365), (2059.225, 5002.41), (2069.27, 5002.41), (2079.315, 5002.41), (2069.27, 5012.455), (2079.315, 5012.455), (2079.315, 5022.5), (2089.36, 5012.455), (2099.405, 5002.41), (2109.45, 4992.365), (2119.495, 5002.41), (2129.54, 4992.365), (2139.585, 4992.365), (2149.63, 4992.365), (2159.675, 4992.365), (2169.72, 4992.365), (2179.765, 4992.365), (2189.81, 4992.365), (2199.855, 4992.365), (2209.9, 4992.365), (2219.945, 4992.365), (2229.99, 4992.365), (2240.035, 4992.365), (2240.035, 5002.41), (2250.08, 5012.455), (2250.08, 5002.41), (2250.08, 4992.365), (2250.08, 4982.32), (2250.08, 4972.275), (2250.08, 4962.23), (2250.08, 4952.185), (2250.08, 4942.14), (2250.08, 4932.095), (2250.08, 4922.05), (2250.08, 4912.005), (2250.08, 4901.96), (2260.125, 4891.915), (2270.17, 4881.87), (2280.215, 4871.825), (2280.215, 4881.87), (2270.17, 4891.915), (2260.125, 4901
# ...

# %%
x_start, y_start = 3000, 4000
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(3003.455, 3997.91), (2993.41, 4007.955), (2983.365, 4018.0), (2973.32, 4028.045), (2983.365, 4038.09), (2973.32, 4038.09), (2973.32, 4048.1349999999998), (2963.275, 4058.18), (2963.275, 4068.225), (2963.275, 4078.27), (2963.275, 4088.315), (2963.275, 4098.36), (2963.275, 4108.405), (2963.275, 4118.45), (2963.275, 4128.495), (2963.275, 4138.54), (2953.23, 4148.585), (2963.275, 4158.63), (2963.275, 4168.675), (2963.275, 4178.72), (2963.275, 4188.765), (2953.23, 4198.81), (2963.275, 4198.81), (2973.32, 4198.81), (2983.365, 4198.81), (2993.41, 4198.81), (3003.455, 4208.855), (2993.41, 4208.855), (3003.455, 4218.9), (2993.41, 4228.945), (2983.365, 4238.99), (2973.32, 4249.035), (2963.275, 4259.08), (2963.275, 4269.125), (2963.275, 4279.17), (2963.275, 4289.215), (2963.275, 4299.26), (2953.23, 4299.26), (2943.185, 4309.305), (2953.23, 4319.35), (2963.275, 4329.3949999999995), (2953.23, 4329.3949999999995), (2963.275, 4339.44), (2953.23, 4339.44), (2943.185, 4339.44), (293
# ...

# %%
x_start, y_start = 4100, 5000

camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(4098.36, 5002.41), (4098.36, 4992.365), (4098.36, 4982.32), (4098.36, 4972.275), (4098.36, 4962.23), (4088.315, 4962.23), (4078.27, 4972.275), (4068.225, 4982.32), (4058.18, 4992.365), (4058.18, 4982.32), (4058.18, 4972.275), (4058.18, 4962.23), (4058.18, 4952.185), (4058.18, 4942.14), (4048.1349999999998, 4932.095), (4038.09, 4942.14), (4038.09, 4952.185), (4038.09, 4962.23), (4038.09, 4972.275), (4038.09, 4982.32), (4038.09, 4992.365), (4038.09, 5002.41), (4038.09, 5012.455), (4038.09, 5022.5), (4038.09, 5032.545), (4038.09, 5042.59), (4038.09, 5052.635), (4038.09, 5062.68), (4028.045, 5052.635), (4028.045, 5042.59), (4028.045, 5032.545), (4028.045, 5022.5), (4028.045, 5012.455), (4028.045, 5002.41), (4028.045, 4992.365), (4028.045, 4982.32), (4028.045, 4972.275), (4028.045, 4962.23), (4028.045, 4952.185), (4028.045, 4942.14), (4028.045, 4932.095), (4028.045, 4922.05), (4018.0, 4912.005), (4018.0, 4922.05), (4007.955, 4912.005), (3997.91, 4912.005), (3997.91, 4922
# ...

# %%
x_start, y_start = 2600, 4500
camino_recorrido_crater(crater_map,x_start,y_start)
# Out:
# La solución es: [(2601.655, 4500.16), (2611.7, 4510.205), (2611.7, 4520.25), (2611.7, 4530.295), (2611.7, 4540.34), (2611.7, 4550.385), (2601.655, 4550.385), (2611.7, 4560.43), (2621.745, 4570.475), (2631.79, 4580.5199999999995), (2631.79, 4590.565), (2641.835, 4600.61), (2641.835, 4610.655), (2631.79, 4610.655), (2641.835, 4620.7), (2631.79, 4620.7), (2621.745, 4610.655), (2611.7, 4610.655), (2621.745, 4620.7), (2631.79, 4630.745), (2621.745, 4640.79), (2631.79, 4650.835), (2641.835, 4660.88), (2641.835, 4670.925), (2631.79, 4680.97), (2621.745, 4691.015), (2611.7, 4701.06), (2601.655, 4711.105), (2591.61, 4721.15), (2581.565, 4731.195), (2571.52, 4741.24), (2571.52, 4751.285), (2581.565, 4741.24), (2591.61, 4731.195), (2601.655, 4721.15), (2611.7, 4711.105), (2621.745, 4701.06), (2631.79, 4691.015), (2641.835, 4680.97), (2651.88, 4670.925), (2661.925, 4660.88), (2671.97, 4650.835), (2682.015, 4640.79), (2682.015, 4650.835), (2682.015, 4660.88), (2682.015, 4670.925), (2671.97, 4680.
# ...
