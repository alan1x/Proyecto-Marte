# %%
from Greedy_funcion import *
import numpy as np
mars_map = np.load("../../Datos/mars_map.npy")

# %% [markdown]
# # Greedy search

# %%
x_start, y_start = 2850, 6400
x_goal, y_goal = 3150, 6800
camino_recorrido(mars_map,x_start,y_start,x_goal,y_goal)
# Out:
# La solución es: [(2852.78, 6398.665), (2862.825, 6408.71), (2872.87, 6418.755), (2882.915, 6428.8), (2892.96, 6438.845), (2903.005, 6448.89), (2913.05, 6458.935), (2923.095, 6468.98), (2933.14, 6479.025), (2943.185, 6489.07), (2953.23, 6499.115), (2963.275, 6509.16), (2973.32, 6519.205), (2983.365, 6529.25), (2993.41, 6539.295), (3003.455, 6549.34), (3013.5, 6559.385), (3023.545, 6569.43), (3033.59, 6579.475), (3043.6349999999998, 6589.5199999999995), (3053.68, 6599.565), (3063.725, 6609.61), (3073.77, 6619.655), (3083.815, 6629.7), (3093.86, 6639.745), (3103.905, 6649.79), (3113.95, 6659.835), (3123.995, 6669.88), (3134.04, 6679.925), (3144.085, 6689.97), (3154.13, 6700.015), (3154.13, 6710.06), (3154.13, 6720.105), (3154.13, 6730.15), (3154.13, 6740.195), (3154.13, 6750.24), (3154.13, 6760.285), (3154.13, 6770.33), (3154.13, 6780.375), (3154.13, 6790.42), (3154.13, 6800.465)]
# Longitud del camino: 41
# Altura de la meta: 128.31951660156264
# ...

# %%
x_start, y_start = 2850, 6400
x_goal, y_goal = 3150, 5000
camino_recorrido(mars_map,x_start,y_start,x_goal,y_goal)
# Out:
# La solución es: [(2852.78, 6398.665), (2862.825, 6388.62), (2872.87, 6378.575), (2882.915, 6368.53), (2892.96, 6358.485), (2903.005, 6348.44), (2913.05, 6338.3949999999995), (2923.095, 6328.35), (2933.14, 6318.305), (2943.185, 6308.26), (2953.23, 6298.215), (2963.275, 6288.17), (2973.32, 6278.125), (2983.365, 6268.08), (2993.41, 6258.035), (3003.455, 6247.99), (3013.5, 6237.945), (3023.545, 6227.9), (3033.59, 6217.855), (3043.6349999999998, 6207.81), (3053.68, 6197.765), (3063.725, 6187.72), (3073.77, 6177.675), (3083.815, 6167.63), (3093.86, 6157.585), (3103.905, 6147.54), (3113.95, 6137.495), (3123.995, 6127.45), (3134.04, 6117.405), (3144.085, 6107.36), (3154.13, 6097.315), (3154.13, 6087.2699999999995), (3154.13, 6077.225), (3154.13, 6067.18), (3154.13, 6057.135), (3154.13, 6047.09), (3154.13, 6037.045), (3154.13, 6027.0), (3154.13, 6016.955), (3154.13, 6006.91), (3154.13, 5996.865), (3154.13, 5986.82), (3154.13, 5976.775), (3154.13, 5966.73), (3154.13, 5956.685), (3154.13, 5946.
# ...

# %%
x_start, y_start = 2850, 6400
x_goal, y_goal = 6000, 7000
camino_recorrido(mars_map,x_start,y_start,x_goal,y_goal)
# Out:
# La solución es: [(2852.78, 6398.665), (2862.825, 6408.71), (2872.87, 6418.755), (2882.915, 6428.8), (2892.96, 6438.845), (2903.005, 6448.89), (2913.05, 6458.935), (2923.095, 6468.98), (2933.14, 6479.025), (2943.185, 6489.07), (2953.23, 6499.115), (2963.275, 6509.16), (2973.32, 6519.205), (2983.365, 6529.25), (2993.41, 6539.295), (3003.455, 6549.34), (3013.5, 6559.385), (3023.545, 6569.43), (3033.59, 6579.475), (3043.6349999999998, 6589.5199999999995), (3053.68, 6599.565), (3063.725, 6609.61), (3073.77, 6619.655), (3083.815, 6629.7), (3093.86, 6639.745), (3103.905, 6649.79), (3113.95, 6659.835), (3123.995, 6669.88), (3134.04, 6679.925), (3144.085, 6689.97), (3154.13, 6700.015), (3164.175, 6710.06), (3174.22, 6720.105), (3184.265, 6730.15), (3194.31, 6740.195), (3204.355, 6750.24), (3214.4, 6760.285), (3224.445, 6770.33), (3234.49, 6780.375), (3244.535, 6790.42), (3254.58, 6800.465), (3264.625, 6810.51), (3274.67, 6820.555), (3284.715, 6830.6), (3294.7599999999998, 6840.6449999999995),
# ...
