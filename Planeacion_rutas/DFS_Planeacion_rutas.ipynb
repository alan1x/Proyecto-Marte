# %%
from DFS_funcion import *
import numpy as np
mars_map = np.load('../Datos/mars_map.npy')
nr, nc = mars_map.shape
scale=10.0174

# %% [markdown]
# # DFS

# %%
origen=(2850,6400)
destino=(3150,6800)
r_origen, c_origen = cyr(mars_map, origen[0], origen[1], scale)
r_destino, c_destino = cyr(mars_map, destino[0], destino[1], scale)

camino_dfs = dfs(mars_map, (r_origen, c_origen), (r_destino, c_destino))

# %%
imagen(camino_dfs,origen,destino,mars_map,nc,nr)
