# %%
from funciones import *
import numpy as np
mars_map = np.load('../Datos/mars_map.npy')
nr, nc = mars_map.shape
scale=10.0174

# %% [markdown]
# # BFS

# %%
origen=(2850,6400)
destino=(3000,6800)
camino=bfs(mars_map,origen,destino)
print(camino[0:10])
print(len(camino))
print(distancia(camino,scale))
# Out:
# [(2850, 6400), (2850, 6401), (2850, 6402), (2850, 6403), (2850, 6404), (2850, 6405), (2850, 6406), (2850, 6407), (2850, 6408), (2850, 6409)]
# 401
# 5649.813600000047

# %%
imagen(camino,origen,destino,mars_map,nc,nr)

# %% [markdown]
# # A*

# %%
origen=(5100,5000)
destino=(5500,2600)
camino=a_estrella(mars_map,origen,destino)
print(camino[0:10])
print(len(camino))
print(distancia(camino,scale))
# Out:
# [(5100, 5000), (5101, 4999), (5102, 4998), (5103, 4997), (5104, 4996), (5105, 4995), (5106, 4994), (5107, 4993), (5108, 4992), (5109, 4991)]
# 2563
# 39308.2775999999

# %%
imagen(camino,origen,destino,mars_map,nc,nr)
